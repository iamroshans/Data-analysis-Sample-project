# %%
#Library	         axis=0 (Vertical)	axis=1 (Horizontal)
# Pandas	     Rows (e.g., drop rows)	Columns (e.g., drop columns)
# NumPy	Columns (e.g., sum along columns)	Rows (e.g., sum along rows)

# %%
import pandas as pd

# %%
df=pd.read_csv("file.csv")

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.shape
# Out:
# (432, 15)

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
df.sample(5)
# Out:
#            Make               Model   Type  Origin DriveTrain      MSRP  \
# 28          BMW            325i 4dr  Sedan  Europe       Rear  $28,495
# 51        Buick  LeSabre Custom 4dr  Sedan     USA      Front  $26,470
# 415  Volkswagen         Phaeton 4dr  Sedan  Europe      Front  $65,000
# 206        Jeep       Liberty Sport    SUV     USA        All  $20,130
# 421       Volvo             S40 4dr  Sedan  Europe      Front  $25,135
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 28   $26,155          2.5        6.0       184.0      20.0         29.0
# 51   $24,282          3.8        6.0       205.0      20.0         29.0
# 415  $59,912          4.2        8.0       335.0      16.0         22.0
# 206  $18,973          2.4        4.0       150.0      20.0         24.0
# 421  $23,701          1.9        4.0       170.0      22.0         29.0
#
#      Weight  Wheelbase  Length
# 28   3219.0      107.0   176.0
# 51   3567.0      112.0   200.0
# ...

# %% [markdown]
# 1) Instruction( For Data cleaning)
#    - Find all Null values in the dataset. If there is any null value in any column, then fill it with the mean of that column.

# %%
df.drop_duplicates(inplace=True) #in df, checks for each row with another one on whole column basis.
df.reset_index(inplace=True)
# df.drop(columns=['index','level_0'],inplace=True) #In drop, inplace is required.

# %%
df
# Out:
#      level_0  index   Make                    Model   Type  Origin DriveTrain  \
# 0          0      0  Acura                      MDX    SUV    Asia        All
# 1          1      1  Acura           RSX Type S 2dr  Sedan    Asia      Front
# 2          2      2  Acura                  TSX 4dr  Sedan    Asia      Front
# 3          3      3  Acura                   TL 4dr  Sedan    Asia      Front
# 4          4      4  Acura               3.5 RL 4dr  Sedan    Asia      Front
# ..       ...    ...    ...                      ...    ...     ...        ...
# 423      423    423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front
# 424      424    424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front
# 425      425    425  Volvo               S80 T6 4dr  Sedan  Europe      Front
# 426      426    426  Volvo                      V40  Wagon  Europe      Front
# 427      427    427  Volvo                     XC70  Wagon  Europe        All
#
# ...

# %%
# df.drop(columns=['index','level_0'],inplace=True) #In drop, inplace is required.
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.isnull().sum() #checking any null value in any columns.
# Out:
# level_0        0
# index          0
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df['Cylinders'].fillna(df['Cylinders'].mean(),inplace=True) #filling Null value in Cylinders column with its mean.

# %%
df.isnull().sum()
# Out:
# level_0        0
# index          0
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# 2) Question (Based on value counts)
#    - Check what are the different types of Make are there in our dataset And what is the count(Occurence) of each Make in the data?

# %%
df['Make'].nunique()
# Out:
# 38

# %% [markdown]
# There are 38 different types of Make found.

# %%
df['Make'].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %% [markdown]
# 3) Instruction (Filtering)
#    - Show all the records -where Origin is Asia or Europe.

# %%
df.sample(5)
# Out:
#      level_0  index        Make            Model    Type  Origin DriveTrain  \
# 219      219    219       Lexus           LX 470     SUV    Asia        All
# 27        27     27         BMW          X5 4.4i     SUV  Europe        All
# 367      367    367      Suzuki       Aeno S 4dr   Sedan    Asia      Front
# 204      204    204         Kia       Sorento LX     SUV    Asia      Front
# 295      295    295  Mitsubishi  Eclipse GTS 2dr  Sports    Asia      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 219  $64,800   $56,455          4.7        8.0       235.0      13.0
# 27   $52,195   $47,720          4.4        8.0       325.0      16.0
# 367  $12,884   $12,719          2.3        4.0       155.0      25.0
# 204  $19,635   $18,630          3.5        6.0       192.0      16.0
# 295  $25,092   $23,456          3.0        6.0       210.0      21.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# 219         17.0  5590.0      112.0   193.0
# ...

# %%
df[(df['Origin']=='Asia') | (df['Origin']=='Europe')]
# Out:
#      level_0  index   Make                    Model   Type  Origin DriveTrain  \
# 0          0      0  Acura                      MDX    SUV    Asia        All
# 1          1      1  Acura           RSX Type S 2dr  Sedan    Asia      Front
# 2          2      2  Acura                  TSX 4dr  Sedan    Asia      Front
# 3          3      3  Acura                   TL 4dr  Sedan    Asia      Front
# 4          4      4  Acura               3.5 RL 4dr  Sedan    Asia      Front
# ..       ...    ...    ...                      ...    ...     ...        ...
# 423      423    423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front
# 424      424    424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front
# 425      425    425  Volvo               S80 T6 4dr  Sedan  Europe      Front
# 426      426    426  Volvo                      V40  Wagon  Europe      Front
# 427      427    427  Volvo                     XC70  Wagon  Europe        All
#
# ...

# %% [markdown]
# 4) Instruction (Removing unwanted records)
#    - Remove all the records (rows) where weight is above 4000.

# %%
df.sample(5)
# Out:
#      level_0  index    Make                  Model   Type Origin DriveTrain  \
# 315      315    315  Nissan              Murano SL  Wagon   Asia       Rear
# 309      309    309  Nissan                Quest S  Sedan   Asia      Front
# 1          1      1   Acura         RSX Type S 2dr  Sedan   Asia      Front
# 124      124    124    Ford           Focus SE 4dr  Sedan    USA      Front
# 54        54     54   Buick  Park Avenue Ultra 4dr  Sedan    USA      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 315  $28,739   $27,300          3.5        6.0       245.0      20.0
# 309  $24,780   $22,958          3.5        6.0       240.0      19.0
# 1    $23,820   $21,761          2.0        4.0       200.0      24.0
# 124  $15,460   $14,496          2.0        4.0       130.0      26.0
# 54   $40,720   $36,927          3.8        6.0       240.0      18.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# 315         25.0  3801.0      111.0   188.0
# ...

# %%
df=df[~(df['Weight']>4000)]

# %%
df['Weight'].max() #checking whether this column has greater than 4000 value or not
# Out:
# 3992.0

# %%
df
# Out:
#      level_0  index   Make                    Model   Type  Origin DriveTrain  \
# 1          1      1  Acura           RSX Type S 2dr  Sedan    Asia      Front
# 2          2      2  Acura                  TSX 4dr  Sedan    Asia      Front
# 3          3      3  Acura                   TL 4dr  Sedan    Asia      Front
# 4          4      4  Acura               3.5 RL 4dr  Sedan    Asia      Front
# 5          5      5  Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front
# ..       ...    ...    ...                      ...    ...     ...        ...
# 423      423    423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front
# 424      424    424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front
# 425      425    425  Volvo               S80 T6 4dr  Sedan  Europe      Front
# 426      426    426  Volvo                      V40  Wagon  Europe      Front
# 427      427    427  Volvo                     XC70  Wagon  Europe        All
#
# ...

# %% [markdown]
# 5) Instruction (Applying function on a column)
#    - Increase all the values of 'MPG_City' column by 3.

# %%
df['MPG_City']=df['MPG_City'].apply(lambda x : x+3)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2124\1296997797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MPG_City']=df['MPG_City'].apply(lambda x : x+3)

# %%
df
# Out:
#      level_0  index   Make                    Model   Type  Origin DriveTrain  \
# 1          1      1  Acura           RSX Type S 2dr  Sedan    Asia      Front
# 2          2      2  Acura                  TSX 4dr  Sedan    Asia      Front
# 3          3      3  Acura                   TL 4dr  Sedan    Asia      Front
# 4          4      4  Acura               3.5 RL 4dr  Sedan    Asia      Front
# 5          5      5  Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front
# ..       ...    ...    ...                      ...    ...     ...        ...
# 423      423    423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front
# 424      424    424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front
# 425      425    425  Volvo               S80 T6 4dr  Sedan  Europe      Front
# 426      426    426  Volvo                      V40  Wagon  Europe      Front
# 427      427    427  Volvo                     XC70  Wagon  Europe        All
#
# ...
