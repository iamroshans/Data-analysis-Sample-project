# %% [markdown]
# This Netflix Dataset has information about TV shows and Movies available on Netflix till 2021.
# This dataset is collected from Flixable which is third-Party Netflix search engine, and available on kaggle website for free.

# %%
import pandas as pd

# %%
df=pd.read_csv('file.csv')

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head() #shows first 5 rows data
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail() #shows last 5 rows data
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.sample(5) #shows 5 random sample rows data
# Out:
#      Show_Id Category                      Title  \
# 6374   s6373  TV Show                The Fosters
# 1541   s1542  TV Show               Criminal: UK
# 157     s158    Movie                     A Choo
# 1369   s1370    Movie  Christmas Wedding Planner
# 873     s874    Movie                Beynelmilel
#
#                                   Director  \
# 6374                                   NaN
# 1541                                   NaN
# 157                    Kevin Ko, Peter Tsi
# 1369                        Justin G. Dyck
# 873   Muharrem Gülmez, Sırrı Süreyya Önder
#
#                                                    Cast  \
# 6374  Teri Polo, Sherri Saum, Jake T. Austin, Hayden...
# 1541  Katherine Kelly, Lee Ingleby, Mark Stanley, Ro...
# 157   Kai Ko, Ariel Lin, Darren Wang, Zhang Xiaolong...
# 1369                   Stephen Huszar, Kelly Rutherford
# 873   Cezmi Baskın, Özgü Namal, Umut Kurt, Nazmi Kır...
#
# ...

# %%
df.shape #gives rows and column number in table
# Out:
# (7789, 11)

# %%
df.size #gives the total number of element (count Nan value also)
# Out:
# 85679

# %%
df.columns #gives info on all the columns name.
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes #gives data types of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info() #gives info on datatypes and non null values count for each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Task 1) is there any duplicate record in this dataset? If yes, then remove the duplicate records.

# %%
df.shape #knowing the no of rows
# Out:
# (7789, 11)

# %%
df.duplicated().sum() #summing the duplicated data
# Out:
# 2

# %% [markdown]
# 2 duplicates found

# %%
df[df.duplicated()] #showing duplicated data(rows basis)
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True) #Deleted duplicates data.

# %%
df[df.duplicated()] #checking if duplicates exist.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ### Task 2) is there any Null values present in any column? Show with heat-map.

# %%
df.isnull().sum() #finding the null values in each column.
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Q 1) For 'House of Cards', what is the show id and who is the director of this show?

# %%
df.sample(3)
# Out:
#      Show_Id Category                       Title                Director  \
# 1556   s1557    Movie                      Curtiz  Tamas Yvan Topolanszky
# 1816   s1817    Movie  Don't Go Breaking My Heart              Johnnie To
# 2648   s2649  TV Show             Haters Back Off                     NaN
#
#                                                    Cast        Country  \
# 1556  Ferenc Lengyel, Evelin Dobos, Declan Hannigan,...        Hungary
# 1816                 Louis Koo, Gao Yuanyuan, Daniel Wu      Hong Kong
# 2648  Colleen Ballinger, Angela Kinsey, Steve Little...  United States
#
#           Release_Date Rating   Duration  \
# 1556    March 25, 2020  TV-MA     99 min
# 1816  December 1, 2018  TV-PG    115 min
# 2648  October 20, 2017  TV-PG  2 Seasons
#
#                                                  Type  \
# 1556                     Dramas, International Movies
# 1816  Comedies, International Movies, Romantic Movies
# ...

# %%
df[df['Title']=='House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
a=df[df['Title']=='House of Cards']
a['Director']
# Out:
# 2832    Robin Wright, David Fincher, Gerald McRaney, J...
# Name: Director, dtype: object

# %% [markdown]
# ***Conclusions: Show id of House of cards is s2833 and Directors are Robin Wright, David Fincher, Gerald McRaney, J...***

# %% [markdown]
# ### Q.3) In which year, highest number of the TV shows and movies were released? Show with Bar graph.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 988.1+ KB

# %%
df['Date_N']=pd.to_datetime(df['Release_Date'],errors='coerce')
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df['Date_N'].isnull().sum()
# Out:
# 98

# %%
df['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ***conclusions : 2136 movies were released in 2019 which is the highest one.***

# %%
df['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# ### Q 3) How many movies and TV shows are in the dataset? Show with Bar graph.

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.sample()
# Out:
#      Show_Id Category          Title                   Director  \
# 6562   s6561    Movie  The last hour  Eduardo Mendoza de Echave
#
#                                                    Cast      Country  \
# 6562  Pietro Sibille, Nidia Bermejo, Toño Vega, Tomm...  Chile, Peru
#
#        Release_Date Rating Duration                          Type  \
# 6562  June 15, 2018  TV-MA  119 min  Dramas, International Movies
#
#                                             Description     Date_N
# 6562  In this compelling true story, two Peruvian de... 2018-06-15

# %%
df.groupby('Category')['Category'].value_counts()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
df.groupby('Category')['Category'].value_counts().plot(kind='bar')
# sns.countplot(df['Category'])
# Out:
# <Axes: xlabel='Category'>

# %%
#Alternative using seaborn
sns.countplot(data=df,x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Q 4) Show all the movies that were released in year 2000.

# %%
df.sample()
# Out:
#      Show_Id Category               Title       Director  \
# 1274   s1275    Movie  Chaotic Love Poems  Garin Nugroho
#
#                                Cast    Country     Release_Date Rating  \
# 1274  Chicco Jerikho, Pevita Pearce  Indonesia  January 5, 2019  TV-14
#
#      Duration                                           Type  \
# 1274   86 min  Dramas, International Movies, Romantic Movies
#
#                                             Description     Date_N
# 1274  Spanning the 1970s, ‘80s and ‘90s, this lyrica... 2019-01-05

# %%
df['year']=df['Date_N'].dt.year

# %%
df.sample() # checking if df['year'] is created or not.
# Out:
#      Show_Id Category                                       Title Director  \
# 3556   s3557  TV Show  Leah Remini: Scientology and the Aftermath      NaN
#
#                           Cast        Country      Release_Date Rating  \
# 3556  Leah Remini, Mike Rinder  United States  November 1, 2020  TV-14
#
#        Duration        Type  \
# 3556  3 Seasons  Docuseries
#
#                                             Description     Date_N    year
# 3556  Former Scientology members share detailed acco... 2020-11-01  2020.0

# %%
df[(df['year']==2020) & (df['Category']=='Movie')] # Movies released in 2020.
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# ### Q 5) Show only the titles of all TV shows that were released in India only.

# %%
df.sample()
# Out:
#      Show_Id Category            Title Director  \
# 1239   s1240  TV Show  Castle of Stars      NaN
#
#                                                    Cast Country  \
# 1239  Chaiyapol Pupart, Jintanutda Lummakanon, Worra...     NaN
#
#            Release_Date Rating  Duration  \
# 1239  September 7, 2018  TV-MA  1 Season
#
#                                                    Type  \
# 1239  International TV Shows, Romantic TV Shows, TV ...
#
#                                             Description     Date_N    year
# 1239  As four couples with different lifestyles go t... 2018-09-07  2018.0

# %%
df[(df['Country']=='India') & (df['Category']=='TV Show')]['Title'] #Title of TV show which are released in India only.
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q 6) Show Top 10 directors, who gave the highest number of TV shows and Movies to Netflix.

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# ### Q 7) show all the records, where 'Category is Movie and Type is comedies' or 'Country is United Kinddom'.

# %%
df.sample(4)
# Out:
#      Show_Id Category                Title         Director  \
# 2850   s2851    Movie  How to Stage a Coup      Cal Seville
# 789     s790    Movie                Beats   Chris Robinson
# 1573   s1574    Movie  Dabbe 6: The Return  Hasan Karacadağ
# 1798   s1799    Movie  Dolemite Is My Name     Craig Brewer
#
#                                                    Cast         Country  \
# 2850                                        Cal Seville  United Kingdom
# 789   Khalil Everage, Anthony Anderson, Uzo Aduba, E...   United States
# 1573  Sema Şimşek, Nilay Gök, Volkan Ünal, Fehmi Kar...          Turkey
# 1798  Eddie Murphy, Wesley Snipes, Keegan-Michael Ke...   United States
#
#           Release_Date Rating Duration  \
# 2850      June 1, 2017  TV-14   47 min
# 789      June 19, 2019  TV-MA  110 min
# 1573    April 17, 2019  TV-MA  153 min
# 1798  October 25, 2019      R  118 min
#
#                                               Type  \
# ...

# %%
df[((df['Category']=='Movie') & (df['Type']=='Comedies')) | (df['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q 8) In how many movies/ shows , Tom cruise was cast?

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.nunique()
# Out:
# Show_Id         7787
# Category           2
# Title           7787
# Director        4050
# Cast            6831
# Country          681
# Release_Date    1565
# Rating            14
# Duration         216
# Type             492
# Description     7769
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ***conclusion: Category has two type*** Now we have to find movies/show in which Tom cruise work.

# %%
df['did Tom Cruise play']=df['Cast'].str.contains('Tom Cruise')

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[df['did Tom Cruise play']==True] # When there is true and false value, no need to put  " ".
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description did Tom Cruise play
# 3860  Through chance, human action, past history and...                True
# 5071  A fast-talking yuppie is forced to slow down w...                True

# %% [markdown]
# ***conclusions: Two Movies found where Tom cruise works.***

# %% [markdown]
# ### Q 9) What are the different Ratings defined by NETFLIX.

# %%
df['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %% [markdown]
# ### Q 9.1) How many movies got the 'TV-14' rating in Canada?

# %%
df.sample(4)
# Out:
#      Show_Id Category                                        Title  \
# 4975   s4975    Movie  Prince of Peoria: A Christmas Moose Miracle
# 5219   s5219    Movie                            Rise: Ini Kalilah
# 4153   s4154    Movie                                         Mitt
# 2407   s2408    Movie                            Ghulam-E-Musthafa
#
#                                               Director  \
# 4975                                     Jon Rosenbaum
# 5219  Saw Teong Hin, Nik Amir Mustapha, M.S. Prem Nath
# 4153                                     Greg Whiteley
# 2407                                      Partho Ghosh
#
#                                                    Cast        Country  \
# 4975  Gavin Lewis, Theodore Barnes, Shelby Simmons, ...  United States
# 5219  Remy Ishak, Mira Filzah, Jack Tan, Sangeeta Kr...       Malaysia
# 4153                                        Mitt Romney  United States
# ...

# %%
df[(df['Country']=='Canada') & (df['Rating']=='TV-14') & (df['Category']=='Movie')].shape[0]
# Out:
# 11

# %% [markdown]
# *** Conclusion : 11 Movies having TV-14 rating found in Canada.***

# %% [markdown]
# ### Q 9.2) How many TV show got the 'R' rating, after year 2018?

# %%
df.sample(3)
# Out:
#      Show_Id Category                Title        Director  \
# 2046   s2047    Movie      Everybody Knows  Asghar Farhadi
# 4705   s4706  TV Show          Outer Banks             NaN
# 1711   s1712  TV Show  Designated Survivor             NaN
#
#                                                    Cast               Country  \
# 2046  Penélope Cruz, Javier Bardem, Ricardo Darín, E...  Spain, France, Italy
# 4705  Chase Stokes, Madelyn Cline, Madison Bailey, J...         United States
# 1711  Kiefer Sutherland, Natascha McElhone, Maggie Q...         United States
#
#      Release_Date Rating   Duration  \
# 2046   2019-06-06      R    133 min
# 4705   2020-04-15  TV-MA   1 Season
# 1711   2019-06-07  TV-MA  3 Seasons
#
#                                                  Type  \
# 2046          Dramas, International Movies, Thrillers
# 4705  TV Action & Adventure, TV Dramas, Teen TV Shows
# 1711          Crime TV Shows, TV Dramas, TV Thrillers
#
# ...

# %%
df['Release_Date']=pd.to_datetime(df['Release_Date'], errors='coerce')

# %%
df['Year']=df['Release_Date'].dt.year
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[(df['Year'] > 2018)]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 7         s8    Movie                                      187
# 8         s9    Movie                                      706
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 0                 NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[(df['Year'] > 2018) & (df['Rating'] == 'R') & (df['Category'] =='TV Show')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description did Tom Cruise play  \
# 6437  Trapped at a stagecoach stop as a storm rages ...               False
#
#         Year
# 6437  2019.0

# %% [markdown]
# ***conclusions: 1 Tv show got R rating after 2018.***

# %% [markdown]
# ### Q. 10) What is the maximum duration of a Movie/ Show on Netflix ?

# %%
df.sample()
# Out:
#      Show_Id Category                       Title       Director  \
# 6532   s6531    Movie                    The King   David Michôd
# 2947   s2948    Movie  Iliza Shlesinger: Unveiled    Steve Paley
# 2961   s2962    Movie                 In Darkness  Anthony Byrne
# 782     s783    Movie                 Beary Tales            NaN
#
#                                                    Cast  \
# 6532  Timothée Chalamet, Joel Edgerton, Robert Patti...
# 2947                                   Iliza Shlesinger
# 2961  Natalie Dormer, Ed Skrein, Emily Ratajkowski, ...
# 782                                                 NaN
#
#                                  Country Release_Date Rating Duration  \
# 6532  United Kingdom, Hungary, Australia   2019-11-01      R  141 min
# 2947                       United States   2019-11-19  TV-MA   78 min
# 2961       United Kingdom, United States   2018-09-22  TV-MA  101 min
# 782                        United States   2017-03-01   TV-G   52 min
#
# ...

# %%
df['Minute']=df['Duration'].str.split().str.get(0) # To get 1st number which is in minute from Duration (here season also include but for reducing complexity, i assume season as min as i dnot know season into minute).

# %%
df.sample()
# Out:
#      Show_Id Category                         Title Director  \
# 6332   s6331  TV Show  The End of the F***ing World      NaN
#
#                                                    Cast         Country  \
# 6332  Jessica Barden, Alex Lawther, Steve Oram, Chri...  United Kingdom
#
#      Release_Date Rating   Duration  \
# 6332   2019-11-05  TV-MA  2 Seasons
#
#                                                    Type  \
# 6332  British TV Shows, International TV Shows, TV C...
#
#                                             Description did Tom Cruise play  \
# 6332  A budding teen psychopath and a rebel hungry f...               False
#
#         Year Minute
# 6332  2019.0      2

# %%
df['Minute']=df['Minute'].astype(int) # Converting Minute object type to int type

# %%
df.info() # confirmed int type for Minute column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Show_Id              7787 non-null   object
#  1   Category             7787 non-null   object
#  2   Title                7787 non-null   object
#  3   Director             5399 non-null   object
#  4   Cast                 7069 non-null   object
#  5   Country              7280 non-null   object
#  6   Release_Date         7689 non-null   datetime64[ns]
#  7   Rating               7780 non-null   object
#  8   Duration             7787 non-null   object
#  9   Type                 7787 non-null   object
#  10  Description          7787 non-null   object
#  11  did Tom Cruise play  7069 non-null   object
#  12  Year                 7689 non-null   float64
#  13  Minute               7787 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(11)
# ...

# %%
df['Minute'].max()
# Out:
# 312

# %% [markdown]
# ### Q 11) Which individual country has the highest No of TV shows?

# %%
df.sample()
# Out:
#      Show_Id Category       Title              Director  \
# 6691   s6690    Movie  The Motive  Manuel Martín Cuenca
#
#                                                    Cast        Country  \
# 6691  Javier Gutiérrez, María León, Adelfa Calvo, Ad...  Spain, Mexico
#
#      Release_Date Rating Duration                                    Type  \
# 6691   2018-08-17  TV-MA  114 min  Comedies, Dramas, International Movies
#
#                                             Description did Tom Cruise play  \
# 6691  An aspiring writer with no imagination seeks i...               False
#
#         Year  Minute
# 6691  2018.0     114

# %%
df.groupby('Country')['Category'].value_counts().sort_values(ascending=False)
# Out:
# Country                                                                         Category
# United States                                                                   Movie       1850
# India                                                                           Movie        852
# United States                                                                   TV Show      705
# United Kingdom                                                                  TV Show      204
#                                                                                 Movie        193
#                                                                                             ...
# Indonesia, United States                                                        Movie          1
# Iran, France                                                                    Movie          1
# Ireland, Canada                                                                 Movie          1
# ...

# %% [markdown]
# ***Conclusions: United states has the highest number of Tv shows that is 705.***

# %% [markdown]
# ### Q 12) How can we sort the dataset by year?

# %%
df.sort_values("Release_Date")
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                          ...                   ...
# 6952   s6951  TV Show                   The Tudors                   NaN
# 6998   s6997  TV Show                The West Wing                   NaN
# 7448   s7447  TV Show                      Vroomiz                   NaN
# 7524   s7523  TV Show   Weird Wonders of the World                   NaN
# 7655   s7654  TV Show            Women Behind Bars                   NaN
#
#                                                    Cast  \
# ...

# %% [markdown]
# ### Q 13) Find all the instances where:
# Category is 'Movie' and Type is 'Dramas'
# or
# Category is 'TV show'and Type is 'Kids TV'

# %%
df.sample()
# Out:
#      Show_Id Category        Title Director  \
# 4705   s4706  TV Show  Outer Banks      NaN
#
#                                                    Cast        Country  \
# 4705  Chase Stokes, Madelyn Cline, Madison Bailey, J...  United States
#
#      Release_Date Rating  Duration  \
# 4705   2020-04-15  TV-MA  1 Season
#
#                                                  Type  \
# 4705  TV Action & Adventure, TV Dramas, Teen TV Shows
#
#                                             Description did Tom Cruise play  \
# 4705  On an island of haves and have-nots, teen John...               False
#
#         Year  Minute
# 4705  2020.0       1

# %%
# A
df[(df['Category']=='Movie') & df['Type'].str.contains('Dramas')]
# Out:
#      Show_Id Category     Title           Director  \
# 1         s2    Movie     07:19  Jorge Michel Grau
# 4         s5    Movie        21     Robert Luketic
# 7         s8    Movie       187     Kevin Reynolds
# 10       s11    Movie      1922       Zak Hilditch
# 15       s16    Movie    Oct-01     Kunle Afolayan
# ...      ...      ...       ...                ...
# 7776   s7775    Movie    Zodiac      David Fincher
# 7778   s7777    Movie  Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie       Zoo       Shlok Sharma
# 7784   s7783    Movie      Zozo        Josef Fares
# 7785   s7784    Movie    Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 15    Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...

# %%
# B
df[(df['Category']=='TV Show') & df['Type'].str.contains("Kids' TV")]
# Out:
#      Show_Id Category                           Title     Director  \
# 108     s109  TV Show        3Below: Tales of Arcadia          NaN
# 111     s112  TV Show                         44 Cats          NaN
# 225     s226  TV Show  A Series of Unfortunate Events          NaN
# 276     s277  TV Show                    Abby Hatcher  Kyran Kelly
# 364     s365  TV Show                    Akbar Birbal          NaN
# ...      ...      ...                             ...          ...
# 7758   s7757  TV Show                              Z4          NaN
# 7761   s7760  TV Show                       Zak Storm          NaN
# 7768   s7767  TV Show                    Zig & Sharko          NaN
# 7777   s7776  TV Show                      Zoids Wild          NaN
# 7779   s7778  TV Show                     Zombie Dumb          NaN
#
#                                                    Cast  \
# 108   Tatiana Maslany, Diego Luna, Nick Offerman, Ni...
# ...
